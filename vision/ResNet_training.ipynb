# %%
# Connecting drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change directory into the git folder
GIT_FOLDER_NAME = 'Paper_implementations'
GIT_FOLDER_PATH = f'drive/My Drive/{GIT_FOLDER_NAME}/'
# %cd "{GIT_FOLDER_PATH}"
# Out:
# /content/drive/My Drive/Paper_implementations

# %%
# %pwd
# Out:
# '/content/drive/My Drive/Paper_implementations'

# %%
# Autoreload imported modules
# %load_ext autoreload
# %autoreload 2

# %%
# Reload autoreload
# %reload_ext autoreload

# %% [markdown]
# __Colab instance info__

# %%
#CPU
# !cat /proc/cpuinfo

# %%
#Memory
# !cat /proc/meminfo

# %% [markdown]
# # __ResNets__

# %% [markdown]
# Following this tutorial https://www.youtube.com/watch?v=DkNIBBBvcPs

# %%
# %cd vision
# Out:
# /content/drive/My Drive/Paper_implementations/vision

# %%
from CNN_architectures.ResNet import *
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn

# %%
net = ResNet50()
x = torch.randn(2,3,224,224)
y = net(x).to('cuda')
y.shape
